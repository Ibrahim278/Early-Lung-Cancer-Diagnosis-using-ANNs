# %% [markdown]
# # Train CNN With Transfer Learning on Chest CT Scans Dataset

# %%
# Import Libraries
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, SpatialDropout2D, Activation, Lambda, Flatten, LSTM
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import utils
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
# Out:
# 2024-12-16 06:50:19.183530: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load the Chest CT Scans Dataset
train_data = "Chest CT Scans Dataset/train"
test_data = "Chest CT Scans Dataset/test"
validation_data = "Chest CT Scans Dataset/valid"

normal_folder = '/normal'
adenocarcinoma_folder = '/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib'
large_cell_carcinoma_folder = '/large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa'
squamous_cell_carcinoma_folder = '/squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa'

# %%
# Set the Image Size for Resizing
image_size = (350, 350)

# Initialize the Image Data Generators for Training and Testing
print("Read Training Images From: ", train_data)
print("Read Validation Images From: ", validation_data)

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

train_datagen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# Batch Size
batch_size = 8

# Data Generators
training_generator = train_datagen.flow_from_directory(
    train_data,
    target_size=image_size,
    batch_size=batch_size,
    color_mode="rgb",
    class_mode='categorical'
)

validation_generator = test_datagen.flow_from_directory(
    validation_data,
    target_size=image_size,
    batch_size=batch_size,
    color_mode="rgb",
    class_mode='categorical'
)
# Out:
# Read Training Images From:  Chest CT Scans Dataset/train
# Read Validation Images From:  Chest CT Scans Dataset/valid
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.

# %%
# Callbacks
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1, factor=0.5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=6, verbose=1, restore_best_weights=True)
checkpointer = ModelCheckpoint(filepath='best_model.hdf5', verbose=1, save_best_only=True)

# %%
# Define the number of output classes
output_size = 4

# Pretrained Model
pretrained_model = Xception(weights='imagenet', include_top=False, input_shape=(*image_size, 3))
pretrained_model.trainable = False  # Initially freeze layers

# Create a new model with the pre-trained base and additional layers for classification
# Build the Model
model = Sequential([
    pretrained_model,
    GlobalAveragePooling2D(),
    Dense(output_size, activation='softmax')
])

print("Pretrained model used:")
pretrained_model.summary()

print("Final model created:")
model.summary()

# Compile the model with an optimizer, loss function, and evaluation metric
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# 2024-12-16 06:51:29.459501: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Pretrained model used:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 350, 350, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 174, 174, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 174, 174, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 174, 174, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 172, 172, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 172, 172, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 172, 172, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 172, 172, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 172, 172, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 172, 172, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 172, 172, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 172, 172, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 86, 86, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 86, 86, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 86, 86, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 86, 86, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 86, 86, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 86, 86, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 86, 86, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 86, 86, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 86, 86, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 86, 86, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 43, 43, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 43, 43, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 43, 43, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 43, 43, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 43, 43, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 43, 43, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#  block4_sepconv1_bn (BatchNorma  (None, 43, 43, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 43, 43, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 43, 43, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 43, 43, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 22, 22, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 22, 22, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 22, 22, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 22, 22, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 22, 22, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 22, 22, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 22, 22, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 22, 22, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 22, 22, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 22, 22, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 22, 22, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 22, 22, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 22, 22, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 22, 22, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 22, 22, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 22, 22, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 22, 22, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 22, 22, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 22, 22, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 22, 22, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 22, 22, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 22, 22, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 22, 22, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 22, 22, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 22, 22, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 22, 22, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 22, 22, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 22, 22, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 22, 22, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 22, 22, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 22, 22, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 22, 22, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 22, 22, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 22, 22, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 22, 22, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 22, 22, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 22, 22, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 22, 22, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#  block9_sepconv3_bn (BatchNorma  (None, 22, 22, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 22, 22, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 22, 22, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 22, 22, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 22, 22, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 22, 22, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 22, 22, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 22, 22, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 22, 22, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 22, 22, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 22, 22, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 22, 22, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 22, 22, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 22, 22, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 22, 22, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 22, 22, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 22, 22, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 22, 22, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 22, 22, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 22, 22, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 22, 22, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 22, 22, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 22, 22, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 22, 22, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 22, 22, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 22, 22, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 22, 22, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 22, 22, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 22, 22, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 22, 22, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 22, 22, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 22, 22, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 22, 22, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 22, 22, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 22, 22, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 22, 22, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 22, 22, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 22, 22, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 11, 11, 1024  745472      ['add_10[0][0]']
#                                 )
#
#  block13_pool (MaxPooling2D)    (None, 11, 11, 1024  0           ['block13_sepconv2_bn[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 11, 11, 1024  4096       ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  add_11 (Add)                   (None, 11, 11, 1024  0           ['block13_pool[0][0]',
#                                 )                                 'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 11, 11, 1536  1582080    ['add_11[0][0]']
#  v2D)                           )
#
#  block14_sepconv1_bn (BatchNorm  (None, 11, 11, 1536  6144       ['block14_sepconv1[0][0]']
#  alization)                     )
#
#  block14_sepconv1_act (Activati  (None, 11, 11, 1536  0          ['block14_sepconv1_bn[0][0]']
#  on)                            )
#
#  block14_sepconv2 (SeparableCon  (None, 11, 11, 2048  3159552    ['block14_sepconv1_act[0][0]']
#  v2D)                           )
#
#  block14_sepconv2_bn (BatchNorm  (None, 11, 11, 2048  8192       ['block14_sepconv2[0][0]']
#  alization)                     )
#
#  block14_sepconv2_act (Activati  (None, 11, 11, 2048  0          ['block14_sepconv2_bn[0][0]']
#  on)                            )
#
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 0
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________
# Final model created:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 11, 11, 2048)      20861480
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 4)                 8196
#
# =================================================================
# Total params: 20,869,676
# Trainable params: 8,196
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
# Train Model
# Initial Training (With Frozen Layers)
history = model.fit(
    training_generator,
    steps_per_epoch=len(training_generator),
    epochs=10,  # Shorter initial training
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[learning_rate_reduction, early_stopping, checkpointer]
)

print("Training accuracy =", history.history['accuracy'][-1])
print("Testing accuracy =", history.history['val_accuracy'][-1])
# Out:
# Epoch 1/10
# 77/77 [==============================] - ETA: 0s - loss: 1.0675 - accuracy: 0.5334
# Epoch 1: val_loss improved from inf to 0.95225, saving model to best_model.hdf5
# 77/77 [==============================] - 117s 1s/step - loss: 1.0675 - accuracy: 0.5334 - val_loss: 0.9522 - val_accuracy: 0.5556 - lr: 0.0010
# Epoch 2/10
# 77/77 [==============================] - ETA: 0s - loss: 0.8203 - accuracy: 0.6476
# Epoch 2: val_loss improved from 0.95225 to 0.87971, saving model to best_model.hdf5
# 77/77 [==============================] - 112s 1s/step - loss: 0.8203 - accuracy: 0.6476 - val_loss: 0.8797 - val_accuracy: 0.5278 - lr: 0.0010
# Epoch 3/10
# 77/77 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.7145
# Epoch 3: val_loss improved from 0.87971 to 0.87616, saving model to best_model.hdf5
# 77/77 [==============================] - 390s 5s/step - loss: 0.6852 - accuracy: 0.7145 - val_loss: 0.8762 - val_accuracy: 0.5694 - lr: 0.0010
# Epoch 4/10
# 77/77 [==============================] - ETA: 0s - loss: 0.6273 - accuracy: 0.7602
# Epoch 4: val_loss improved from 0.87616 to 0.81072, saving model to best_model.hdf5
# 77/77 [==============================] - 115s 1s/step - loss: 0.6273 - accuracy: 0.7602 - val_loss: 0.8107 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 5/10
# 77/77 [==============================] - ETA: 0s - loss: 0.5707 - accuracy: 0.7977
# Epoch 5: val_loss improved from 0.81072 to 0.74795, saving model to best_model.hdf5
# 77/77 [==============================] - 125s 2s/step - loss: 0.5707 - accuracy: 0.7977 - val_loss: 0.7479 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 6/10
# 77/77 [==============================] - ETA: 0s - loss: 0.5204 - accuracy: 0.8303
# Epoch 6: val_loss did not improve from 0.74795
# 77/77 [==============================] - 114s 1s/step - loss: 0.5204 - accuracy: 0.8303 - val_loss: 0.8039 - val_accuracy: 0.6389 - lr: 0.0010
# Epoch 7/10
# 77/77 [==============================] - ETA: 0s - loss: 0.4786 - accuracy: 0.8532
# Epoch 7: val_loss improved from 0.74795 to 0.72309, saving model to best_model.hdf5
# 77/77 [==============================] - 116s 2s/step - loss: 0.4786 - accuracy: 0.8532 - val_loss: 0.7231 - val_accuracy: 0.6806 - lr: 0.0010
# Epoch 8/10
# 77/77 [==============================] - ETA: 0s - loss: 0.4483 - accuracy: 0.8679
# Epoch 8: val_loss improved from 0.72309 to 0.68567, saving model to best_model.hdf5
# 77/77 [==============================] - 120s 2s/step - loss: 0.4483 - accuracy: 0.8679 - val_loss: 0.6857 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 9/10
# 77/77 [==============================] - ETA: 0s - loss: 0.4253 - accuracy: 0.8695
# Epoch 9: val_loss did not improve from 0.68567
# 77/77 [==============================] - 118s 2s/step - loss: 0.4253 - accuracy: 0.8695 - val_loss: 0.7736 - val_accuracy: 0.6528 - lr: 0.0010
# Epoch 10/10
# 77/77 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.8907
# Epoch 10: val_loss improved from 0.68567 to 0.66619, saving model to best_model.hdf5
# 77/77 [==============================] - 121s 2s/step - loss: 0.3957 - accuracy: 0.8907 - val_loss: 0.6662 - val_accuracy: 0.7361 - lr: 0.0010
# Training accuracy = 0.8907014727592468
# Testing accuracy = 0.7361111044883728

# %%
# Plot Model Loss and Accuracy

# Function to display training curves for loss and accuracy
def plot_accuracy_loss(training, validation, title, subplot):
    if subplot % 10 == 1:
        plt.subplots(figsize=(10, 10), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model ' + title)
    ax.set_ylabel(title)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid.'])

# Display training curves for loss and accuracy
plot_accuracy_loss(history.history['loss'], history.history['val_loss'], 'loss', 211)
plot_accuracy_loss(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 212)

# %%
# Fine-tune the Model
pretrained_model.trainable = True  # Unfreeze layers

# Recompile the Model with a Lower Learning Rate
model.compile(optimizer=Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Fine-tuning Training
fine_tune_history = model.fit(
    training_generator,
    steps_per_epoch=len(training_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[learning_rate_reduction, early_stopping, checkpointer]
)
# Out:
# Epoch 1/50
# 77/77 [==============================] - ETA: 0s - loss: 1.2008 - accuracy: 0.5057
# Epoch 1: val_loss did not improve from 0.66619
# 77/77 [==============================] - 441s 6s/step - loss: 1.2008 - accuracy: 0.5057 - val_loss: 0.9685 - val_accuracy: 0.6111 - lr: 1.0000e-05
# Epoch 2/50
# 77/77 [==============================] - ETA: 0s - loss: 0.7341 - accuracy: 0.7325
# Epoch 2: val_loss did not improve from 0.66619
# 77/77 [==============================] - 643s 8s/step - loss: 0.7341 - accuracy: 0.7325 - val_loss: 1.0236 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 3/50
# 77/77 [==============================] - ETA: 0s - loss: 0.5312 - accuracy: 0.8320
# Epoch 3: val_loss did not improve from 0.66619
# 77/77 [==============================] - 476s 6s/step - loss: 0.5312 - accuracy: 0.8320 - val_loss: 0.9921 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 4/50
# 77/77 [==============================] - ETA: 0s - loss: 0.4256 - accuracy: 0.8695
# Epoch 4: val_loss did not improve from 0.66619
# 77/77 [==============================] - 474s 6s/step - loss: 0.4256 - accuracy: 0.8695 - val_loss: 0.8854 - val_accuracy: 0.5972 - lr: 1.0000e-05
# Epoch 5/50
# 77/77 [==============================] - ETA: 0s - loss: 0.2969 - accuracy: 0.9299
# Epoch 5: val_loss did not improve from 0.66619
# 77/77 [==============================] - 475s 6s/step - loss: 0.2969 - accuracy: 0.9299 - val_loss: 0.7817 - val_accuracy: 0.6528 - lr: 1.0000e-05
# Epoch 6/50
# 77/77 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9608
# Epoch 6: val_loss did not improve from 0.66619
# 77/77 [==============================] - 472s 6s/step - loss: 0.2080 - accuracy: 0.9608 - val_loss: 0.6942 - val_accuracy: 0.7222 - lr: 1.0000e-05
# Epoch 7/50
# 77/77 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9755
# Epoch 7: val_loss improved from 0.66619 to 0.59461, saving model to best_model.hdf5
# 77/77 [==============================] - 456s 6s/step - loss: 0.1593 - accuracy: 0.9755 - val_loss: 0.5946 - val_accuracy: 0.8333 - lr: 1.0000e-05
# Epoch 8/50
# 77/77 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9723
# Epoch 8: val_loss improved from 0.59461 to 0.53371, saving model to best_model.hdf5
# 77/77 [==============================] - 433s 6s/step - loss: 0.1347 - accuracy: 0.9723 - val_loss: 0.5337 - val_accuracy: 0.8611 - lr: 1.0000e-05
# Epoch 9/50
# 77/77 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9804
# Epoch 9: val_loss improved from 0.53371 to 0.52358, saving model to best_model.hdf5
# 77/77 [==============================] - 3056s 40s/step - loss: 0.1134 - accuracy: 0.9804 - val_loss: 0.5236 - val_accuracy: 0.7917 - lr: 1.0000e-05
# Epoch 10/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9902
# Epoch 10: val_loss improved from 0.52358 to 0.47091, saving model to best_model.hdf5
# 77/77 [==============================] - 471s 6s/step - loss: 0.0784 - accuracy: 0.9902 - val_loss: 0.4709 - val_accuracy: 0.8056 - lr: 1.0000e-05
# Epoch 11/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0871 - accuracy: 0.9804
# Epoch 11: val_loss improved from 0.47091 to 0.41141, saving model to best_model.hdf5
# 77/77 [==============================] - 499s 6s/step - loss: 0.0871 - accuracy: 0.9804 - val_loss: 0.4114 - val_accuracy: 0.8611 - lr: 1.0000e-05
# Epoch 12/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0809 - accuracy: 0.9853
# Epoch 12: val_loss improved from 0.41141 to 0.39716, saving model to best_model.hdf5
# 77/77 [==============================] - 525s 7s/step - loss: 0.0809 - accuracy: 0.9853 - val_loss: 0.3972 - val_accuracy: 0.8611 - lr: 1.0000e-05
# Epoch 13/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9935
# Epoch 13: val_loss improved from 0.39716 to 0.36884, saving model to best_model.hdf5
# 77/77 [==============================] - 530s 7s/step - loss: 0.0555 - accuracy: 0.9935 - val_loss: 0.3688 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 14/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9951
# Epoch 14: val_loss improved from 0.36884 to 0.35958, saving model to best_model.hdf5
# 77/77 [==============================] - 529s 7s/step - loss: 0.0454 - accuracy: 0.9951 - val_loss: 0.3596 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 15/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9886
# Epoch 15: val_loss improved from 0.35958 to 0.34034, saving model to best_model.hdf5
# 77/77 [==============================] - 530s 7s/step - loss: 0.0495 - accuracy: 0.9886 - val_loss: 0.3403 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 16/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9967
# Epoch 16: val_loss improved from 0.34034 to 0.33988, saving model to best_model.hdf5
# 77/77 [==============================] - 1040s 14s/step - loss: 0.0351 - accuracy: 0.9967 - val_loss: 0.3399 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 17/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0438 - accuracy: 0.9967
# Epoch 17: val_loss improved from 0.33988 to 0.33206, saving model to best_model.hdf5
# 77/77 [==============================] - 468s 6s/step - loss: 0.0438 - accuracy: 0.9967 - val_loss: 0.3321 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 18/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.33206
# 77/77 [==============================] - 475s 6s/step - loss: 0.0336 - accuracy: 1.0000 - val_loss: 0.3544 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 19/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9951
# Epoch 19: val_loss improved from 0.33206 to 0.32827, saving model to best_model.hdf5
# 77/77 [==============================] - 452s 6s/step - loss: 0.0281 - accuracy: 0.9951 - val_loss: 0.3283 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 20/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9951
# Epoch 20: val_loss improved from 0.32827 to 0.30885, saving model to best_model.hdf5
# 77/77 [==============================] - 438s 6s/step - loss: 0.0366 - accuracy: 0.9951 - val_loss: 0.3088 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 21/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0340 - accuracy: 0.9902
# Epoch 21: val_loss did not improve from 0.30885
# 77/77 [==============================] - 700s 9s/step - loss: 0.0340 - accuracy: 0.9902 - val_loss: 0.3288 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 22/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9984
# Epoch 22: val_loss did not improve from 0.30885
# 77/77 [==============================] - 1340s 18s/step - loss: 0.0159 - accuracy: 0.9984 - val_loss: 0.3364 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Epoch 23/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9967
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 23: val_loss did not improve from 0.30885
# 77/77 [==============================] - 1376s 18s/step - loss: 0.0229 - accuracy: 0.9967 - val_loss: 0.3299 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 24/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9935
# Epoch 24: val_loss did not improve from 0.30885
# 77/77 [==============================] - 433s 6s/step - loss: 0.0225 - accuracy: 0.9935 - val_loss: 0.3387 - val_accuracy: 0.8750 - lr: 5.0000e-06
# Epoch 25/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9935
# Epoch 25: val_loss did not improve from 0.30885
# 77/77 [==============================] - 583s 8s/step - loss: 0.0267 - accuracy: 0.9935 - val_loss: 0.3233 - val_accuracy: 0.9028 - lr: 5.0000e-06
# Epoch 26/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9984
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# Restoring model weights from the end of the best epoch: 20.
#
# Epoch 26: val_loss did not improve from 0.30885
# 77/77 [==============================] - 451s 6s/step - loss: 0.0165 - accuracy: 0.9984 - val_loss: 0.3161 - val_accuracy: 0.9028 - lr: 5.0000e-06
# Epoch 26: early stopping

# %%
print("Training accuracy =", fine_tune_history.history['accuracy'][-1])
print("Testing accuracy =", fine_tune_history.history['val_accuracy'][-1])
# Out:
# Training accuracy = 0.9983686804771423
# Testing accuracy = 0.9027777910232544

# %%
# Plot Model Loss and Accuracy

# Combine histories from initial training and fine-tuning
history_combined = {
    'accuracy': history.history['accuracy'] + fine_tune_history.history['accuracy'],
    'val_accuracy': history.history['val_accuracy'] + fine_tune_history.history['val_accuracy'],
    'loss': history.history['loss'] + fine_tune_history.history['loss'],
    'val_loss': history.history['val_loss'] + fine_tune_history.history['val_loss']
}

# Plot Training and Validation Accuracy
plt.figure(figsize=(12, 6))
plt.plot(history_combined['accuracy'], label='Train Accuracy')
plt.plot(history_combined['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy During Training and Fine-Tuning')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# Plot Training and Validation Loss
plt.figure(figsize=(12, 6))
plt.plot(history_combined['loss'], label='Train Loss')
plt.plot(history_combined['val_loss'], label='Validation Loss')
plt.title('Model Loss During Training and Fine-Tuning')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import classification_report
import numpy as np

# Create the test data generator
test_generator = test_datagen.flow_from_directory(
    test_data,
    target_size=image_size,
    batch_size=batch_size,
    color_mode="rgb",
    class_mode='categorical',
    shuffle=False  # Ensure order is preserved for evaluation
)

# Predict on the test set
test_steps = np.ceil(test_generator.samples / test_generator.batch_size).astype(int)
predictions = model.predict(test_generator, steps=test_steps, verbose=1)

# Convert predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)

# Get the true class labels
true_classes = test_generator.classes

# Get the class labels (mapping indices to class names)
class_labels = list(test_generator.class_indices.keys())

# Print the classification report
print("Classification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Found 315 images belonging to 4 classes.
# 40/40 [==============================] - 58s 1s/step
# Classification Report:
#                          precision    recall  f1-score   support
#
#          adenocarcinoma       0.88      0.88      0.88       120
#    large.cell.carcinoma       0.85      0.88      0.87        51
#                  normal       1.00      0.96      0.98        54
# squamous.cell.carcinoma       0.91      0.91      0.91        90
#
#                accuracy                           0.90       315
#               macro avg       0.91      0.91      0.91       315
#            weighted avg       0.91      0.90      0.91       315

# %%
pretrained_model.save("Models/Transfer Learning_Chest CT Scans Dataset.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Making Predictions on Chest CT Scans Dataset

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
def load_and_preprocess_image(img_path, target_size):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Rescale the image like the training images
    return img_array

# %%
# Load, preprocess, and predict the class of an image
img_path = 'Chest CT Scans Dataset/test/adenocarcinoma/000108 (3).png'
img = load_and_preprocess_image(img_path, image_size)
predictions = model.predict(img)
predicted_class = np.argmax(predictions[0])
class_labels = list(training_generator.class_indices.keys())
predicted_label = class_labels[predicted_class]

print(f"The image belongs to class: {predicted_label}")

# Display the image with the predicted class
plt.imshow(image.load_img(img_path, target_size=image_size))
plt.title(f"Predicted: {predicted_label}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 1s 521ms/step
# The image belongs to class: adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib

# %%
# Repeat the process for additional images
img_path = 'Chest CT Scans Dataset/test/large.cell.carcinoma/000110.png'
img = load_and_preprocess_image(img_path, image_size)
predictions = model.predict(img)
predicted_class = np.argmax(predictions[0])
predicted_label = class_labels[predicted_class]
print(f"The image belongs to class: {predicted_label}")
plt.imshow(image.load_img(img_path, target_size=image_size))
plt.title(f"Predicted: {predicted_label}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 425ms/step
# The image belongs to class: large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa

# %%
img_path = 'Chest CT Scans Dataset/test/normal/10 (2).png'
img = load_and_preprocess_image(img_path, image_size)
predictions = model.predict(img)
predicted_class = np.argmax(predictions[0])
predicted_label = class_labels[predicted_class]
print(f"The image belongs to class: {predicted_label}")
plt.imshow(image.load_img(img_path, target_size=image_size))
plt.title(f"Predicted: {predicted_label}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 389ms/step
# The image belongs to class: normal

# %%
img_path = 'Chest CT Scans Dataset/test/squamous.cell.carcinoma/000111.png'
img = load_and_preprocess_image(img_path, image_size)
predictions = model.predict(img)
predicted_class = np.argmax(predictions[0])
predicted_label = class_labels[predicted_class]
print(f"The image belongs to class: {predicted_label}")
plt.imshow(image.load_img(img_path, target_size=image_size))
plt.title(f"Predicted: {predicted_label}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 458ms/step
# The image belongs to class: squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa
